# %%
import pandas as pd

# %%
path = r"D:/Kanishka/@inventing/codinggg/Languages/Python/DVP/DVP Website+Presentation/EV-Population-Insights/data/raw data/Electric_Vehicle_Population_Data.csv"

df = pd.read_csv(path)

print ("Number of rows and columns")
print(df.shape)

print("FIrst 10 rows")
df.head(10)
# Out:
# Number of rows and columns
# (194232, 17)
# FIrst 10 rows
#    VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0  1C4RJXN66R  Snohomish       Everett    WA      98204.0        2024
# 1  KNDJX3AEXG       King        Renton    WA      98058.0        2016
# 2  5YJ3E1EA3L       King       Seattle    WA      98125.0        2020
# 3  1G1RC6S5XH     Kitsap  Port Orchard    WA      98367.0        2017
# 4  5UXTA6C09P  Snohomish        Monroe    WA      98272.0        2023
# 5  1FMCU0EZXN     Yakima         Moxee    WA      98936.0        2022
# 6  5YJSA1DNXD   Thurston       Olympia    WA      98506.0        2013
# 7  1N4AZ0CP8F  Snohomish        Monroe    WA      98272.0        2015
# 8  WP1AE2A21J  Snohomish       Everett    WA      98208.0        2018
# 9  1N4BZ1BV4N  Snohomish       Everett    WA      98208.0        2022
#
#         Make     Model                   Electric Vehicle Type  \
# 0       JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
df.columns.tolist()

df.dtypes
# Out:
# VIN (1-10)                                               str
# County                                                   str
# City                                                     str
# State                                                    str
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                     str
# Model                                                    str
# Electric Vehicle Type                                    str
# Clean Alternative Fuel Vehicle (CAFV) Eligibility        str
# Electric Range                                       float64
# Base MSRP                                            float64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                         str
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 9
# City                                                   9
# State                                                  0
# Postal Code                                            9
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         2
# Base MSRP                                              2
# Legislative District                                 432
# DOL Vehicle ID                                         0
# Vehicle Location                                      13
# Electric Utility                                       9
# ...

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  194223.000000  194232.000000   194230.000000  194230.000000
# mean    98175.800678    2020.781807       54.835458     978.730732
# std      2435.345863       2.999041       89.614355    7988.719011
# min      1731.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 75%     98372.000000    2023.000000       68.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         193800.000000    1.942320e+05       1.942230e+05
# mean              29.009954    2.248923e+08       5.297532e+10
# std               14.901335    7.357830e+07       1.607770e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %%
df.drop(
    columns=[
        "VIN (1-10)",
        "State",
        "DOL Vehicle ID",
        "Legislative District",
        "2020 Census Tract"
    ],
    inplace=True
)

# %%
df.columns.tolist()

df.dtypes
# Out:
# County                                                   str
# City                                                     str
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                     str
# Model                                                    str
# Electric Vehicle Type                                    str
# Clean Alternative Fuel Vehicle (CAFV) Eligibility        str
# Electric Range                                       float64
# Base MSRP                                            float64
# Vehicle Location                                         str
# Electric Utility                                         str
# dtype: object
